# %%
testowy = {
  "university": {
    "name": "University of Example",
    "location": {
      "city": "Warsaw",
      "country": "Poland",
      "campuses": [
        {
          "id": "C1",
          "name": "Main Campus",
          "address": {
            "street": "Main Street 1",
            "postalCode": "00-001"
          },
          "buildings": [
            {
              "code": "A",
              "rooms": [
                {
                  "roomNumber": "A101",
                  "capacity": 40,
                  "equipment": ["projector", "whiteboard", "speakers"],
                  "schedule": {
                    "monday": [
                      {
                        "courseId": "CS101",
                        "from": "08:00",
                        "to": "09:30"
                      },
                      {
                        "courseId": "DS202",
                        "from": "10:00",
                        "to": "11:30"
                      }
                    ],
                    "tuesday": [],
                    "wednesday": [
                      {
                        "courseId": "CS101",
                        "from": "12:00",
                        "to": "13:30"
                      }
                    ]
                  }
                },
                {
                  "roomNumber": "A102",
                  "capacity": 30,
                  "equipment": [],
                  "schedule": null
                }
              ]
            },
            {
              "code": "B",
              "rooms": []
            }
          ]
        },
        {
          "id": "C2",
          "name": "Remote Campus",
          "address": null,
          "buildings": []
        }
      ]
    },
    "faculties": [
      {
        "id": "F1",
        "name": "Faculty of Computer Science",
        "departments": [
          {
            "id": "D1",
            "name": "Department of Data Science",
            "programmes": [
              {
                "code": "DS-MSc",
                "name": "Data Science MSc",
                "mode": ["full-time", "part-time"],
                "coordinators": [
                  {
                    "id": "T001",
                    "name": {
                      "first": "Anna",
                      "last": "Kowalska"
                    },
                    "email": "anna.kowalska@example.edu",
                    "roles": ["coordinator", "lecturer"],
                    "officeHours": {
                      "online": true,
                      "slots": [
                        {
                          "day": "Monday",
                          "from": "14:00",
                          "to": "16:00"
                        },
                        {
                          "day": "Wednesday",
                          "from": "10:00",
                          "to": "11:00"
                        }
                      ]
                    }
                  }
                ]
              }
            ]
          }
        ]
      }
    ]
  },
  "courses": [
    {
      "id": "CS101",
      "title": "Introduction to Programming",
      "ects": 6,
      "semester": 1,
      "tags": ["python", "basics", "programming"],
      "instructors": [
        {
          "id": "T002",
          "name": "Jan Nowak",
          "email": "jan.nowak@example.edu"
        }
      ],
      "syllabus": {
        "weeks": [
          {
            "week": 1,
            "topic": "Python basics",
            "subtopics": ["variables", "types", "input/output"],
            "materials": [
              {
                "type": "slides",
                "url": "https://example.edu/cs101/week1/slides",
                "metadata": {
                  "format": "pdf",
                  "pages": 45
                }
              },
              {
                "type": "notebook",
                "url": "https://example.edu/cs101/week1/notebook",
                "metadata": {
                  "language": "python",
                  "requirements": ["python>=3.10", "jupyter"]
                }
              }
            ]
          },
          {
            "week": 2,
            "topic": "Control structures",
            "subtopics": ["if", "elif", "else", "loops"],
            "materials": []
          }
        ]
      },
      "assessments": [
        {
          "type": "homework",
          "id": "HW1",
          "weight": 0.2,
          "rubric": {
            "criteria": [
              {
                "name": "correctness",
                "maxPoints": 10
              },
              {
                "name": "code_style",
                "maxPoints": 5
              }
            ]
          },
          "submissions": [
            {
              "studentId": "S001",
              "submittedAt": "2025-03-01T10:15:00Z",
              "files": [
                {
                  "filename": "hw1_s001.py",
                  "sizeBytes": 2048
                }
              ],
              "grade": {
                "points": 13,
                "feedback": "Good job, minor style issues."
              }
            },
            {
              "studentId": "S003",
              "submittedAt": null,
              "files": [],
              "grade": null
            }
          ]
        },
        {
          "type": "exam",
          "id": "EX1",
          "weight": 0.8,
          "details": {
            "format": "written",
            "durationMinutes": 90,
            "allowedMaterials": ["pen", "paper"]
          },
          "resultsSummary": {
            "average": 3.75,
            "min": 2.0,
            "max": 5.0,
            "distribution": [
              {
                "grade": 2.0,
                "count": 5
              },
              {
                "grade": 3.0,
                "count": 8
              },
              {
                "grade": 4.0,
                "count": 10
              },
              {
                "grade": 5.0,
                "count": 2
              }
            ]
          }
        }
      ]
    },
    {
      "id": "DS202",
      "title": "Advanced JSON & APIs",
      "ects": 4,
      "semester": 2,
      "tags": ["json", "apis", "data_structures"],
      "instructors": [
        {
          "id": "T003",
          "name": "Maria Example",
          "email": "maria.example@example.edu"
        }
      ],
      "config": {
        "project": {
          "phases": [
            {
              "name": "design",
              "required": true,
              "maxTeams": 10,
              "deliverables": [
                "schema.json",
                "README.md"
              ]
            },
            {
              "name": "implementation",
              "required": true,
              "maxTeams": 8,
              "deliverables": [
                "app.py",
                "requirements.txt",
                {
                  "optional": [
                    "docker-compose.yml",
                    "openapi.yaml"
                  ]
                }
              ]
            },
            {
              "name": "presentation",
              "required": false,
              "maxTeams": null,
              "deliverables": []
            }
          ],
          "constraints": {
            "languagesAllowed": ["python", "javascript"],
            "frameworks": {
              "python": ["fastapi", "flask"],
              "javascript": ["express", "next.js"]
            },
            "maxTeamSize": 4
          }
        }
      }
    }
  ],
  "students": [
    {
      "id": "S001",
      "name": {
        "first": "Katarzyna",
        "last": "Wiśniewska"
      },
      "active": true,
      "yearOfStudy": 1,
      "enrolment": {
        "programmeCode": "DS-MSc",
        "startYear": 2025,
        "mode": "full-time"
      },
      "contacts": {
        "emails": [
          "katarzyna.w@example.com",
          "k.wisniewska@student.example.edu"
        ],
        "phone": null
      },
      "preferences": {
        "languages": ["python", "r"],
        "topics": [
          "data_science",
          "machine_learning",
          {
            "advanced": [
              "graph_databases",
              "knowledge_graphs"
            ]
          }
        ]
      },
      "enrolledCourses": [
        {
          "courseId": "CS101",
          "status": "passed",
          "finalGrade": 4.5
        },
        {
          "courseId": "DS202",
          "status": "ongoing",
          "finalGrade": null
        }
      ]
    },
    {
      "id": "S002",
      "name": {
        "first": "Piotr",
        "last": "Nowak"
      },
      "active": false,
      "yearOfStudy": 2,
      "enrolment": {
        "programmeCode": "DS-MSc",
        "startYear": 2024,
        "mode": "part-time"
      },
      "contacts": {
        "emails": [],
        "phone": "+48 123 456 789"
      },
      "preferences": {
        "languages": ["python"],
        "topics": []
      },
      "enrolledCourses": []
    },
    {
      "id": "S003",
      "name": {
        "first": "Zofia",
        "last": "Krawczyk"
      },
      "active": true,
      "yearOfStudy": 1,
      "enrolment": {
        "programmeCode": "DS-MSc",
        "startYear": 2025,
        "mode": "full-time"
      },
      "contacts": {
        "emails": [
          "zofia.k@example.com"
        ],
        "phone": null
      },
      "preferences": {
        "languages": [],
        "topics": [
          "visualization"
        ]
      },
      "enrolledCourses": [
        {
          "courseId": "CS101",
          "status": "ongoing",
          "finalGrade": null
        }
      ]
    }
  ],
  "metadata": {
    "generatedAt": "2025-12-06T11:00:00Z",
    "version": 1,
    "notes": [
      "This JSON is intended for indexing and access exercises.",
      {
        "hint": "Try accessing deep nested values using Python indexing.",
        "examples": [
          "students[0]['preferences']['topics'][2]['advanced'][1]",
          "courses[0]['assessments'][0]['submissions'][0]['grade']['points']",
          "university['location']['campuses'][0]['buildings'][0]['rooms'][0]['schedule']['monday'][1]['courseId']"
        ]
      }
    ]
  }
}
