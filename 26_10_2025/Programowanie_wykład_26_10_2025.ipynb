# %%
print()

# %%
3 + 3

3 / 3

#integer
#float

"napis"

True
False

#typy proste

"3"
3

# %%
12 > 15
12 < 15

# %%
if
elif
else

# %%
if 12 > 15:
  print("12 jest większe od 15")
elif 12 == 15:
  print("12 jest rowne 15")
elif 12 >= 15:
  print("12 jest wieksze lub rowne 15")
elif 12 > 15:
  print("")
else:
  print("żaden inny przypadek")
# Out:
# żaden inny przypadek

# %%
#zmienne

imie = "patryk"

#zmienne zapisywane są w pamięci komputera (pamięci operacyjnej)

# %%
print(imie)
# Out:
# patryk

# %%
liczba = 12

# %%
print(liczba)
# Out:
# 12

# %%
print(liczba)
# Out:
# 12

# %%
#struktury danych vs typ danych

x = 12

#Lista

imie1 = "Patryk"
imie2 = "Ola"
imie3 = "Maciek"

# %%
lista_imion = ["Patryk", "Ola", "Maciek"]

# %%
print(lista_imion)
# Out:
# ['Patryk', 'Ola', 'Maciek']

# %%
#Czym jest struktura danych?

# %%
type(lista_imion)
# Out:
# list

# %%
lista_imion_zmienne = [imie1, imie2, imie3]

# %%
print(lista_imion_zmienne)
# Out:
# ['Patryk', 'Ola', 'Maciek']

# %%
print()

# %%
#Metody

lista_imion.append("Zosia")

# %%
lista_imion
# Out:
# ['Patryk', 'Ola', 'Maciek', 'Zosia']

# %%
lista_imion.append("Karol")

# %%
lista_imion
# Out:
# ['Patryk', 'Ola', 'Maciek', 'Zosia', 'Karol']

# %%
#Listy mozna modyfikować

# %%
imie = "Patryk"

# %%
imie.upper()
# Out:
# 'PATRYK'

# %%
imie
# Out:
# 'Patryk'

# %%
imie = imie.upper() #nadpisanie zmiennej

# %%
imie
# Out:
# 'PATRYK'

# %%
#czy mogę modyfikować typy proste?
#czy mogę modyfikować struktury danych?
#w jaki sposób mogę zmienić wartość typu prostego?

# %%
lista_imion
# Out:
# ['Patryk', 'Ola', 'Maciek', 'Zosia', 'Karol']

# %%
lista_imion.remove("Maciek")

# %%
lista_imion
# Out:
# ['Patryk', 'Ola', 'Zosia', 'Karol']

# %%
lista_imion.sort()

# %%
lista_imion
# Out:
# ['Karol', 'Ola', 'Patryk', 'Zosia']

# %%
lista_cyfr = [2, 5, 3, 1]

# %%
lista_cyfr.sort(reverse=True)

# %%
lista_cyfr
# Out:
# [5, 3, 2, 1]

# %%
#Pętle

imie = "Patryk"

imie.upper()

# %%
print(imie1)
print(imie2)
print(imie3)
# Out:
# Patryk
# Ola
# Maciek

# %%
print(imie1.upper())
print(imie2.upper())
print(imie3.upper())

# %%
#Pętla FOR


#Pętla for oznacza że wykonujemy tę samą czynność dla każdego elementu osobno
#W innych językach pętla for oznacza for each

#Iteracja
#Iterowanie

#DLA KAŻDEGO ELEMENTU NA LIŚCIE:
  #wykonaj czynność na tym elemencie


lista_imion
# Out:
# ['Karol', 'Ola', 'Patryk', 'Zosia']

# %%
for imie in lista_imion:
  print(imie)
# Out:
# Karol
# Ola
# Patryk
# Zosia

# %%
liczby = [1, 2, 3, 4, 5]

# %%
print(liczby)
# Out:
# [1, 2, 3, 4, 5]

# %%
for liczba in liczby:
  print(liczba * 2)
# Out:
# 2
# 4
# 6
# 8
# 10

# %%
lista_imion
# Out:
# ['Karol', 'Ola', 'Patryk', 'Zosia']

# %%
for imie in lista_imion:
  print(imie.upper())
# Out:
# KAROL
# OLA
# PATRYK
# ZOSIA

# %%
liczby
# Out:
# [1, 2, 3, 4, 5]

# %%
for liczba in liczby:
  if liczba == 4:
    print("to jest liczba 4")
  elif liczba != 4:
    print("ta konkretna liczba z listy nie jest 4")
# Out:
# ta konkretna liczba z listy nie jest 4
# ta konkretna liczba z listy nie jest 4
# ta konkretna liczba z listy nie jest 4
# to jest liczba 4
# ta konkretna liczba z listy nie jest 4

# %%
#Pętla WHILE

#pętle określone -- pętla FOR
#pętle nieokreślone -- pętla WHILE

# %%
#DOPÓKI warunek jest lub nie jest spełniony:
  #wykonuj czynność

# %%
licznik = 0
granica = 12

# %%
while licznik < granica:
  print(licznik)
  #infinite loop
  licznik = licznik + 1 #inkrementacja
  #inkrementacja oznacza zwiększanie
  #przeciwnością inkrementacji jest dekrementacja czyli zmniejszanie
